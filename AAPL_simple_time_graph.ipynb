# %%
import numpy as np #python library for scientific computing
import pandas as pd #python library for data manipulation and analysis
import matplotlib.pyplot as plt #python library for charting
from pandas_datareader import data as pdr #extract data from internet sources into pandas data frame

# %%
# !pip install yfinance --upgrade --no-cache-dir
# Out:
# Requirement already satisfied: yfinance in c:\users\eray\anaconda3\lib\site-packages (0.2.3)
# Requirement already satisfied: pytz>=2022.5 in c:\users\eray\anaconda3\lib\site-packages (from yfinance) (2022.7)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\eray\anaconda3\lib\site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\eray\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\eray\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\eray\anaconda3\lib\site-packages (from yfinance) (1.21.5)
# Requirement already satisfied: html5lib>=1.1 in c:\users\eray\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: cryptography>=3.3.2 in c:\users\eray\anaconda3\lib\site-packages (from yfinance) (37.0.1)
# Requirement already satisfied: requests>=2.26 in c:\users\eray\anaconda3\lib\site-packages (from yfinance) (2.28.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\eray\anaconda3\lib\site-packages (from yfinance) (2.3.4)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\eray\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\eray\anaconda3\lib\site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\eray\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\eray\anaconda3\lib\site-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: six>=1.9 in c:\users\eray\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\eray\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\eray\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\eray\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\eray\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\eray\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\eray\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2022.9.24)
# Requirement already satisfied: pycparser in c:\users\eray\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)

# %%
import yfinance as yf
yf.pdr_override()

# %%
data = pdr.get_data_yahoo('^DJI', start='2006-01-01')
data2 = pdr.get_data_yahoo('MSFT', start='2006-01-01')
data3 = pdr.get_data_yahoo('AAPL', start='2016-01-01')
data4 = pdr.get_data_yahoo('BB.TO', start='2006-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
ax = (data['Close'] / data['Close'].iloc[0] * 100).plot(figsize=(15, 6))
(data2['Close'] / data2['Close'].iloc[0] * 100).plot(ax=ax, figsize=(15,6))
(data3['Close'] / data3['Close'].iloc[0] * 100).plot(ax=ax, figsize=(15,6))
(data4['Close'] / data4['Close'].iloc[0] * 100).plot(ax=ax, figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
data3.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2016-01-04  25.652500  26.342501  25.500000  26.337500  24.111500  270597600
# 2016-01-05  26.437500  26.462500  25.602501  25.677500  23.507278  223164000
# 2016-01-06  25.139999  25.592501  24.967501  25.174999  23.047249  273829600
# 2016-01-07  24.670000  25.032499  24.107500  24.112499  22.074554  324377600
# 2016-01-08  24.637501  24.777500  24.190001  24.240000  22.191277  283192000

# %%
data3.shape
# Out:
# (1754, 6)

# %%
close = data3["Close"]
close.head()
# Out:
# Date
# 2016-01-04    26.337500
# 2016-01-05    25.677500
# 2016-01-06    25.174999
# 2016-01-07    24.112499
# 2016-01-08    24.240000
# Name: Close, dtype: float64

# %%
close.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
close.index
# Out:
# DatetimeIndex(['2016-01-04', '2016-01-05', '2016-01-06', '2016-01-07',
#                '2016-01-08', '2016-01-11', '2016-01-12', '2016-01-13',
#                '2016-01-14', '2016-01-15',
#                ...
#                '2022-12-06', '2022-12-07', '2022-12-08', '2022-12-09',
#                '2022-12-12', '2022-12-13', '2022-12-14', '2022-12-15',
#                '2022-12-16', '2022-12-19'],
#               dtype='datetime64[ns]', name='Date', length=1754, freq=None)

# %%
close.index = pd.DatetimeIndex(close.index)

# %%
close.head()
# Out:
# Date
# 2016-01-04    26.337500
# 2016-01-05    25.677500
# 2016-01-06    25.174999
# 2016-01-07    24.112499
# 2016-01-08    24.240000
# Name: Close, dtype: float64

# %%
close.plot()
# Out:
# <AxesSubplot:xlabel='Date'>
